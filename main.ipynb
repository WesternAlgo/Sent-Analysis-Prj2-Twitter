# %%
from test import *

# %%
url = create_twitter_url()
data = process_yaml()
bearer_token = create_bearer_token(data)
res_json = twitter_auth_and_connect(bearer_token, url)

# %%
# Out:
# {'data': [{'id': '1549117711694848001',
#    'text': '@ianmSC Mask use Japan (IHME)\n1. Masks do not prevent 100% of infections, they help *reduce* infections vs no mask\n2. Japan loosened some measures, eg travel\n3. BA.5 vs susceptible popn = case spike\n4. Controlled mask studies best to assess masks, less confounds.\nhttps://t.co/dEHIi0Oq7B https://t.co/Mr68cKoRzk'},
#   {'id': '1549113925920346113',
#    'text': "@Wontevertweet27 I see you intend on sharing more misleading information to my followers so I will be blocking you. To answer your question, outbreak data is collected by prov's not HC, data has been biased and underreported since prov testing stopped and using deaths across categ.  is absurd."},
#   {'id': '1549102807550230533',
#    'text': 'Infections do add additional immunity protection (and harm from infection) but the whole "hybrid immunity defence package" is also subject to increased evasion and waning. What are completely resistant to immune evasion?  \nMasks and ventilation.'},
#   {'id': '1549102805973188610',
#    'text': 'To synthesize what I think experts are finding lately, they expect Omicron variants to continue developing mostly along the immune evasion path where there are still several genomic opportunities and less along the transmissibility path where there are fewer obvious gains.'},
#   {'id': '1549097304652660738',
#    'text': "@MoriartyLab @danwalker9999 @DFisman I haven't emailed with a correction but I did message @ONdigital  open data team for an explanation and correction as needed. They appear to have restarted the original deaths column in their dataset that they ceased on March 11th. I have heard nothing back. \ncc @ONThealth https://t.co/AC0TbNKsBU"},
#   {'id': '1549060042674081792',
#    'text': "@TheVagabond_Jon You're welcome. 20 million lives saved in the first year. And they are continuing to have a major impact in 2022 saving lives because they continue to defend well against severe outcomes, see UKHSA reports.\nhttps://t.co/8achEcjliz"},
#   {'id': '1549056050376097792',
#    'text': '@Wontevertweet27 You do realize that \n1) fatalities are strongly related to age\n2) original outbreak does not describe forward chain of transmission to more vulnerable\n3) regular testing and tracing &gt;&gt;&gt; in LTCs/healthcare vs bars, stores and parties etc (lol)\n=&gt; this is a nonsense interpretation'},
#   {'id': '1549048860583944193',
#    'text': 'Japan has one of the best records in the world in managing #covid19 and its simple messaging is based on knowledge that #COVIDisAirborne and cluster outbreaks contribute significantly to spread. \n(PS 87% wear masks.) https://t.co/ieUxYLbXCQ'},
#   {'id': '1549023825265934339',
#    'text': '"But with masks, distancing, travel restrictions, and other protective measures almost entirely vanished, “we’ve given the virus every opportunity to keep doing this,” says David Martinez, a viral immunologist at the University of North Carolina"\n#covid19\nhttps://t.co/dIOGMCo5Lu'},
#   {'id': '1549022983787880448',
#    'text': 'RT @KatharineSmart: Due to the overwhelm of sick children continuing to receive care in the ED they have closed to lower acuity patients.…'},
#   {'id': '1548858861687300100',
#    'text': "@D_Bone It's a data issue. Suggest you delete tweet."},
#   {'id': '1548830233020841984', 'text': 'This should not be a hard question.'},
#   {'id': '1548822018493145090',
#    'text': 'From a US jurisdiction. I want an answer to a very simple question that I believe is important.\nhttps://t.co/2SptrFzhug'},
#   {'id': '1548796051984994306',
#    'text': 'Their reasons have been clear to all except the most naive: politics and economics. Your health was not a priority. Alberta declared endemicity around the time I changed my twitter banner. Nothing I am saying here is new.'},
#   {'id': '1548796050382757888',
#    'text': "Alberta was not alone. Provinces opted to force normal, to declare excessive infections and hospitalizations as normal, to drop mask mandates with no rationale. In short, to declare covid over when it wasn't. Chief Medical Officers of Health are a facade.\nhttps://t.co/jofKGg7tow"},
#   {'id': '1548736864261111810', 'text': 'Cc @IPACCanada'},
#   {'id': '1548724429697466368',
#    'text': "Why does no one in Ontario know the risk of catching covid while in hospital? Where's the data and tracking? Isn't this critical information for Ontarians? \n#onhealth https://t.co/IdpAHYZzBE"},
#   {'id': '1548721972091277312',
#    'text': "I'm asking supporters of Ontario's CMOH to help list his actions and accomplishments in reducing Omicron spread this year. There must be some."},
#   {'id': '1548719571728736256',
#    'text': 'RT @DFisman: Important new work from @JeffTownsend @Alison_Galvani and colleagues at @Yale \n\nDurability of immune protection via mRNA vacci…'},
#   {'id': '1548710339180695554',
#    'text': 'PSA: https://t.co/YsCU92yt78 https://t.co/oEhlRAh5gE'},
#   {'id': '1548705295454674944',
#    'text': 'RT @Billius27: @blarose33 Honestly, I think every jurisdiction in Canada has caused irreparable damage to mask mandates (that were working…'},
#   {'id': '1548704861008584706',
#    'text': '@blarose33 Honestly, I think every jurisdiction in Canada has caused irreparable damage to mask mandates (that were working fine). How much of a rebound is seen if mandates return will depend entirely on public education and a strong and persistent communication campaign. https://t.co/tk5L0oBeBm'},
#   {'id': '1548701691763216384',
#    'text': 'Are we learning from places like Japan or following the lead of places like the US and UK? https://t.co/utShHoXfLZ'},
#   {'id': '1548697198430388230',
#    'text': 'Have we learned how to get smarter or have we learned how to become less smart? https://t.co/Q9M4cPTbF8'},
#   {'id': '1548696210122457096',
#    'text': 'Have we learned how to build herd immunity or have we learned how to build herd stupidity? https://t.co/WljPcuEPVh'},
#   {'id': '1548695340324380674',
#    'text': 'Having we learned to live with a milder Omicron or have we learned to let many die with a more infectious Omicron? https://t.co/fcR7is0iKz'},
#   {'id': '1548694421981597696',
#    'text': 'Are we returning to normal health for the long term or damaging our long term health? https://t.co/CiUKtEDx5t'},
#   {'id': '1548693783432335361',
#    'text': 'Are we successfully living with a milder virus or trying to fill our hospitals by infecting everyone? https://t.co/S61vjBX93Y'},
#   {'id': '1548692923939782657',
#    'text': 'Are we living with covid or letting covid live with us?\n#WearAMask #ONhealth https://t.co/dzVf6Jnfqc'},
#   {'id': '1548689397041750016',
#    'text': "@VH3music @viledeity_ That's one of the sources.  Chart shown is cropped from chart at https://t.co/2V18uZO7fC.  Probability of Omicron transmission for no masking is estimated at 100 seconds (set to 1) and N95/N95 means 102 times longer than no masking.\nFootnotes:\nhttps://t.co/GRSuFaXV1Q"},
#   {'id': '1548684044434563078',
#    'text': '@BigBadJuan Then I will delete. You may have a better one.'},
#   {'id': '1548683513758732289',
#    'text': "@MaryFernando_ Thanks Mary, that's the one, explained more clearly by CNN."},
#   {'id': '1548680293921562625',
#    'text': 'Translation: getting reinfected is a really bad idea.'},
#   {'id': '1548680291715252224',
#    'text': 'I will just point out that although repeat infections *specific to Omicron antigenic drift* may *usually* be less severe than previous ones due to increased hybrid immunity response, the cumulative effect of infections creates higher severe outcome and LC risk, per US Vet study. https://t.co/yiBZ3K38he'},
#   {'id': '1548677815733833728',
#    'text': '@BregmanPs He is the best of humanity and his attackers are the worst, simple as that.'},
#   {'id': '1548676472096833538',
#    'text': '@MikeWaffle_ Of course I do not expect to persuade anyone at this stage of the pandemic who has set other standards or requirements like RCT that are impossible and even unethical in a pandemic. Is there an RCT for parachutes?'},
#   {'id': '1548675434136702976',
#    'text': "@MikeWaffle_ I've shared many of the peer-reviewed and journal-published studies on masks before but this summarizes a lot of them. Also keep in mind that aerosol studies show that covid particles hitchhike on much larger particles, the argument about size is false.\nhttps://t.co/KAmH1AOjWW"},
#   {'id': '1548664064238391296',
#    'text': "Compiled thread with complex preliminary lab results on BA.2.75 from @yunlong_cao's research. May be oversimplified in media I suspect. https://t.co/dvDQFhJEdv"},
#   {'id': '1548661202317975557',
#    'text': 'RT @MartyMakary: Paxlovid overuse in low-risk people can breed resistance and spawn new virus mutations. Another study just out suggests th…'},
#   {'id': '1548658534191190019',
#    'text': 'Research continues on cognitive effects.\n"Even minor adjustments in those myelin can actually impact neuronal communication in quite diverse ways,” she says. “Losing that ability to adaptively respond to neuronal activity led to persistent cognitive impairments in these mice.” " https://t.co/YeEDbBEYAr'},
#   {'id': '1548513824449363968',
#    'text': 'We may see a cascading effect as the BA.5 infection rates rise and smaller locations with less staffing flexibility are overwhelmed. This prospect obviously needs urgent attention by MoH.\nh/t @DGBassani  \nhttps://t.co/suVlYtgapA'},
#   {'id': '1548509269380608002',
#    'text': "@Cthwilson1 Sure, my main focus is overall population risk, not individual - that's more the role of medical professionals."},
#   {'id': '1548506810503544832',
#    'text': "@drDavidKeegan @AntibioticDoc Be good to have a standard but then we don't even have a standard nomenclature for variants. My point is we need to review the evidence and put preliminary policy estimates on the table, otherwise policy makers assume it away and focus only on hospitalization counts."},
#   {'id': '1548506302233673728',
#    'text': '@Dshep48Shepherd This thread might help you captain. Check out the video at the end. Remember, the exhaled virus hitchhikes on larger particles such as water particles or mucus particles. But an N95 mask has much more involved in its technology. https://t.co/0SSJxMzcEk'},
#   {'id': '1548504277642948609',
#    'text': '@drDavidKeegan @AntibioticDoc Note that LitCovid uses the category "Long Covid" itself, see the screenshot.'},
#   {'id': '1548503979016929283',
#    'text': '@AntibioticDoc Whatever we choose to call this long term effect, the Ontario government and CMOH have never mentioned it. And even if defns are unstructured, I doubt the body of evidence can be completely ignored away as zero impact on decisions like mask mandates and vaccine coverage.'},
#   {'id': '1548502174321111043',
#    'text': 'It is strange to have so many studies reported on this (even by the government\'s own expert advisers) and yet not have a single Ontario government official use the phrase "long covid". Strange times indeed. https://t.co/cHn4bv3RZc'},
#   {'id': '1548500185524842498',
#    'text': 'We can wait for studies to prove what clinical outcomes or symptom reports remain after a year or two of Omicron infections sweep the world or we can make preliminary estimates of the impact those infections have and make policy accordingly and now. #precautionaryprinciple'},
#   {'id': '1548499339370061824',
#    'text': 'As a statistician I was trained to consider risk as a function of probabilities, not to assume the probabilities are zero until a year after the risks occur and final answers can be drafted up. That seems to be the binary logic being used by many public health and govt officials.'},
#   {'id': '1548499337407107074',
#    'text': 'Opinion: It is wrong and misleading to carry on a policy discussion about covid risks without including the risk of long covid outcomes from non-hospitalized infections. Every article focusing only on hospitalizations or deaths needs to widen its lens. Long covid is very real.'},
#   {'id': '1548491932732571648',
#    'text': "@JamesDFu @CBCNews @DFisman That's why I wrote a thread about this. I agree younger adults are at lower risk of hospitalization/death so direct severe outcome mitigation from vaccines is less critical than older but there is much else to consider from a population perspective."},
#   {'id': '1548491325850341384',
#    'text': "@JamesDFu @CBCNews @DFisman Don't believe any of the sound bite messaging is holistic enough to satisfy me. Issues like when a bivalent vaccine would be ready, &gt;6 month waning of many 3rd shots, issue of long covid risks, and the issue of helping to limit BA.5 forward transmission come to mind for starters."},
#   {'id': '1548482777707819009',
#    'text': 'RT @charliesmithvcr: Professor of evolutionary biology @TRyanGregory says universities should "lead with empathy" by reinstating mask manda…'},
#   {'id': '1548462696164560896', 'text': '@dogbeay Do I look naive to you?'},
#   {'id': '1548460245269094402',
#    'text': "@winojohn62 Well we know the higher the test positivity, the more testing volumes are insufficient to estimate true infection activity. That's about as far as I would take it - a general indication that infection levels are much higher than testing can identify. Relationship is not linear."},
#   {'id': '1548454401454444544',
#    'text': 'WHO warning about BA.5 - the most transmissible variant yet of SARS-COV-2. Also, names like BA.5 and BA.2.75 will not be changing, they are all Omicron lineages and all are variants of concern. https://t.co/EtxZWtthVT'},
#   {'id': '1548446905662709761', 'text': 'That flag is staying right there.'},
#   {'id': '1548446639005634561',
#    'text': "@DanisGram How do you do a good job when you're hostage to  provinces underfunding hospitals and inundating your staff with infections and poor wages for two and a half years? Let's agree to focus on the big issue."},
#   {'id': '1548445531407454208',
#    'text': 'Why do I have a 🇺🇦 flag next to my name? Because I support the right of free countries to remain free and not be crushed under the jackboot of an invading dictator. If those saying they are for "freedom" don\'t understand this, then they are using "freedom" for selfish reasons.'},
#   {'id': '1548443935613194243',
#    'text': '"If you’ve been infected and recovered but aren’t vaccinated, you’re in trouble with BA.5, which could make you very sick. If you’re under-vaccinated, you could also be in trouble. Those with a single boost four or five months ago could be at risk until they get the second boost"'},
#   {'id': '1548442891458002944',
#    'text': "@DanisGram It isn't the salary of CEOs that is causing this, that's a red herring. It is the encouragement of mass covid infections and hospitalizations leading to health care staff shortages and burnout, while provinces spend $ on  car license plate fee rebates and other political stunts."},
#   {'id': '1548439871944937472',
#    'text': "@viledeity_ Masks indoors are not a political statement, they help you and others avoid covid. It's common sense."},
#   {'id': '1548439249514467337',
#    'text': '@RosieSchwartz @PublicHealthON @DFisman @FarrahSchwartz Disappointing @PublicHealthON. About 1/4 of new infections in England are reinfections and that country is swamped right now with infections.'},
#   {'id': '1548436914067296261', 'text': '@IHoward1749 We will.'},
#   {'id': '1548436413791621127',
#    'text': '@viledeity_ No but you can share this with your followers, if you and they still have open minds. Thanks!\nhttps://t.co/3ma8JYQpaJ https://t.co/Zo0LTwaQsD'},
#   {'id': '1548434384541274113',
#    'text': 'Peter Hotez on #LongCovid:\n"It’s going to haunt our health care systems and country for years. How will we adapt to that? We have to think about someone with an otherwise robust and vigorous lifestyle now in cognitive decline earlier. It’s depressing as hell."'},
#   {'id': '1548433103084875777',
#    'text': '"I think we can still vaccinate our way out of this. I have to think about the long road and the near term. As for the long road, there are several groups working to develop a universal COVID vaccine. One that can handle new variants of concern or brand new SARS viruses"'},
#   {'id': '1548432325947469824',
#    'text': '"The most impactful thing you can do to protect yourself and your family is to be mindful of your vaccine status. Take advantage of what’s available. The next most important thing to do with the transmission going on indoors is to wear a mask. Boy, that’s been a tough sell"'},
#   {'id': '1548431888955482114',
#    'text': '"How much of that is due to transmissibility versus immune escape is up for scientific debate. But there’s no question right now, even if you’re fully vaccinated, you’re at risk of infection. We’re seeing a steep increase in the number of cases."'},
#   {'id': '1548430038755749888',
#    'text': 'Led development of Corbevax vaccine to help vaccinate the world with nothing expected in return, Nobel prize nominee, and now speaks out about BA.5. \n#onhealth https://t.co/dKzkvO7jep'},
#   {'id': '1548400417209364480',
#    'text': 'While I am here: \nhttps://t.co/OzhtuMwauO'},
#   {'id': '1548400155380002823', 'text': '@1947xxx https://t.co/OzhtuMwauO'},
#   {'id': '1548353038976372737',
#    'text': 'If this is happening now in our summer, what will happen this winter? Dysfunctional health care will directly lead to greater health risks and fatality rates for Canadians. This problem is not going away by itself. \n\nhttps://t.co/Nli9TFMx2A'},
#   {'id': '1548313685084364800',
#    'text': "Every time I go indoors to a public venue, I wear my N95 mask and distance. When I do that I am showing respect to all those inside by reducing the chances they get infected by me while also protecting myself. It's a simple thing - respect for others."},
#   {'id': '1548310247936167938',
#    'text': "Besides helping each other stay safe and healthy, we are also helping our hospitals stay open and functioning. Let's pull together as Canadians and put this BA.5 wave behind us. 👍 https://t.co/EQKM6b6TNw"},
#   {'id': '1548308596500209666',
#    'text': 'Footnotes to this chart: https://t.co/GRSuFbfvTo'},
#   {'id': '1548308591513198593',
#    'text': "If we work together we can reduce our odds of infection. For some, that can mean the difference between hospital or enjoying summer. This chart shows that if we *both* wear N95's, we can reduce the relative risk by 102 times compared to both going maskless. \n#MaskUp #covid19 https://t.co/yNWq6QWi0r"},
#   {'id': '1548158148292120576',
#    'text': 'Nothing to see here. https://t.co/bHaaXzH5pd'},
#   {'id': '1548110066422669312',
#    'text': 'RT @kareem_carr: this is a tough one https://t.co/VnPmjJAxBY'},
#   {'id': '1548105913029955586',
#    'text': 'Some medical professionals may be interested in this forward look at the potential efficacy of various monoclonal antibody treatments against BA.4/5 and the VOC lineage under monitoring - BA.2.75.\nhttps://t.co/0qTq5uIZ8F'},
#   {'id': '1548101854193598471',
#    'text': 'If you have objective standards to hire someone, you should have objective standards to fire someone. This is not the first time Dr. Moore has misled the province.'},
#   {'id': '1548097719079563264',
#    'text': "As I stated the other day, Dr. Moore's statement about myocarditis was false. In the interim he has boosted anti-vax narratives and damaged the critical uptake of boosters. This is not public health leadership. He should resign in my opinion.\n#onhealth https://t.co/mo4JAPbi1Z"},
#   {'id': '1548086653746495489',
#    'text': 'PS as for lingering symptoms, yes I had recurrences of painful episodes, they subsided in intensity and frequency over the years. .'},
#   {'id': '1548086341300211712',
#    'text': 'sleep, or concentrate enough for my work. The insurance-appointed doctor told me "pain is not an illness". I always remember that. Two months later I was recovered and able to return to work. Just an anecdote to show I empathize with those forced back to work. /end'},
#   {'id': '1548086339366637568',
#    'text': 'shoes up. At the time I had no shoes with laces. Apparently his copy/paste for the report had been overly zealous. I notified the inse company I would be reporting them and the doctor. They backed off. At the time I was in so much neck/head pain that I could not function well,'},
#   {'id': '1548086337202360320',
#    'text': 'Not all institutional doctors are trustworthy. I had an insurance cmpy-appointed doctor dispute my post-car accident neck injury and declare I was fit to return to work. In their report, I noticed that the doctor reported observing that I was able to bend down and tie my own ..'},
#   {'id': '1548054186180300801',
#    'text': '@JanetGunderson Those eyes. The door-poke look in all dogs 😂'},
#   {'id': '1548052519502241796',
#    'text': 'What could possibly be causing these staff shortages? Random testing at airports? /s https://t.co/DL2PNXalOP'},
#   {'id': '1548050488381214722', 'text': 'Boom. https://t.co/rZjQ8DmJ9T'},
#   {'id': '1548046717626359808',
#    'text': 'impact of Omicron in early 2022, the age distribution of each country, and how deaths are reported in each country.'},
#   {'id': '1548046714228973569',
#    'text': "*Assuming* YTD #covid19 death rates continue through the end of the year, here's a snapshot of selected countries. You can see that Canada will exceed the rates of previous years at its current 2022 pace. From here one can debate issues like excess deaths, the heavy initial ⤵️ https://t.co/kvqz3yNMTw"},
#   {'id': '1548012706703167490',
#    'text': 'RT @Mike_Honey_: The same chart is shown here with a log scale. This can give a clearer picture of relative growth rates.\n\nThe top countrie…'},
#   {'id': '1547997079301017608',
#    'text': '@aMarkzzz Personally I get mine in Ontario via Walmart curb side grocery pickup. Provinces may vary.'},
#   {'id': '1547996407377694722',
#    'text': '@jasonwilhelm80 But if you have a specific medical issue, I am confident you will seek out professional medical advice, just like I would.'},
#   {'id': '1547996042179665922',
#    'text': '@jasonwilhelm80 Hi Jason, I base my tweets on experts, data, and scientific studies across many disciplines over 2.5 years. People are free to see if what I share proves to be reliable and founded in statistical evidence. So far, many professionals and experts follow and support this account.'},
#   {'id': '1547992402924675073',
#    'text': 'Not a day goes by that Twitter does not offer me a trending disinformation hashtag to look at, probably because I use words like covid and vaccines. I am so over twitter as a responsible or honest platform. I am here for a reason but under protest.'},
#   {'id': '1547991580140638212',
#    'text': '@KenButler12 @DaliaHasanMD Yes, hospitalizations are useful and I report those. But they are a small % of the infection spread across the province and are skewed to older age groups etc.'},
#   {'id': '1547988356880994304',
#    'text': 'The current Ontario health strategy is failing. It allows excess infections to hospitals, does little to educate about covid (creating misinformed violence risk), infects nurses so they are understaffed, underpays nurses, and overloads ERs. \n#onhealth https://t.co/JqgH0DwXt1'},
#   {'id': '1547986087515078658',
#    'text': '@KiffNeil Completely false. Rapid tests are highly accurate in detecting infectiousness at a point in time. Sensitivity is generally &gt;98%. They are not marketed or intended to be used as clinical diagnostic tools, they are for infectiousness. \nhttps://t.co/zhAoEqxJHn'},
#   {'id': '1547983094505828352',
#    'text': '@DaliaHasanMD The ~40% case ascertainment is the best estimate of an expert I have  discussed this with privately.'}],
#  'meta': {'newest_id': '1549117711694848001',
#   'oldest_id': '1547983094505828352',
#   'result_count': 100,
#   'next_token': 'b26v89c19zqg8o3fpz2nasvwj42y3bn0hujpoas1r8vwd'}}
